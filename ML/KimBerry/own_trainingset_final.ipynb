# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Welcome back, master")
# Out:
# Num GPUs Available:  1
# Welcome back, master

# %%
import numpy as np 
from d2l import tensorflow as d2l
import matplotlib.pyplot as plt
import cv2 as cv

folder = "C:\\Kim\\image\\" 
files = os.listdir(folder)
data = []
for i, file in enumerate(files):
    image = cv.imread(folder+file)
    image_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
    #print(image_gray.shape)
    re = cv.resize(image_gray, (28,28))
    img = np.reshape(re,(28,28))
    #print(re.shape)
    """เป็นการใช้ if condition ที่สันขวานมาก"""
    if i<20 : 
        data.append([img, 0])
    else:
        data.append([img, 1])
        
np.random.shuffle(data)
features = []
label = []
for j in data:
    features.append(j[0])
    label.append(j[1])

print(features)
print(label)
    #batch = np.array([arr])

# %%
def labels(labels): 
    text_labels = ["infected", "un_infected"]
    return [text_labels[int(i)] for i in labels] 

def show_images(imgs, num_rows, num_cols, titles=None, scale=1.5):  
    """Plot a list of images."""
    figsize = (num_cols * scale, num_rows * scale)
    _, axes = d2l.plt.subplots(num_rows, num_cols, figsize=figsize) 
    axes = axes.flatten() 
    for i, (ax, img) in enumerate(zip(axes, imgs)):
        ax.imshow(img)
        ax.axes.get_xaxis().set_visible(False)
        ax.axes.get_yaxis().set_visible(False)
        if titles:
            ax.set_title(titles[i])
    return axes



    
x = tf.constant(features[:20])
X = tf.reshape(x , (20,28,28))
y = tf.constant(label[:20])
Y = tf.reshape(y, (20,1) )
#print(X.shape)
#print(Y.shape)
show_images(X, 2, 10, titles=labels(y))
# Out:
# array([<AxesSubplot:title={'center':'un_infected'}>,
#        <AxesSubplot:title={'center':'infected'}>,
#        <AxesSubplot:title={'center':'un_infected'}>,
#        <AxesSubplot:title={'center':'un_infected'}>,
#        <AxesSubplot:title={'center':'infected'}>,
#        <AxesSubplot:title={'center':'infected'}>,
#        <AxesSubplot:title={'center':'infected'}>,
#        <AxesSubplot:title={'center':'un_infected'}>,
#        <AxesSubplot:title={'center':'un_infected'}>,
#        <AxesSubplot:title={'center':'infected'}>,
#        <AxesSubplot:title={'center':'un_infected'}>,
#        <AxesSubplot:title={'center':'infected'}>,
#        <AxesSubplot:title={'center':'infected'}>,
#        <AxesSubplot:title={'center':'un_infected'}>,
#        <AxesSubplot:title={'center':'un_infected'}>,
#        <AxesSubplot:title={'center':'un_infected'}>,
#        <AxesSubplot:title={'center':'infected'}>,
#        <AxesSubplot:title={'center':'un_infected'}>,
# ...
